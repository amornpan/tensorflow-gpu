# %% [markdown]
# https://github.com/amornpan/DeepLearning.AI-TensorFlow-Developer-Professional-Certificate/blob/master/1.%20Introduction%20to%20TensorFlow%20for%20Artificial%20Intelligence%2C%20Machine%20Learning%2C%20and%20Deep%20Learning/1.%20A%20New%20Programming%20Paradigm/ungraded_lab/C1_W1_Lab_1_hello_world_nn.ipynb

# %%
https://github.com/amornpan/tensorflow-1-public/tree/main/C1/W1/ungraded_lab

# %% [markdown]
# def hw_function(x):
#     y = (2 * x) - 1
#     return y

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.14.0

# %% [markdown]
# ## Define and Compile the Neural Network

# %%
# # Build a simple Sequential model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Providing the Data

# %%
# Declare model inputs and outputs for training
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
# Train the model
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 6ms/step - loss: 6.7316e-05
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.5934e-05
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.4580e-05
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.3254e-05
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.1954e-05
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.0681e-05
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.9435e-05
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.8215e-05
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 5.7019e-05
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.5847e-05
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4701e-05
# Epoch 12/500
# ...

# %%
# Make a prediction
print(model.predict([10.0]))
# Out:
# 1/1 [==============================] - 0s 52ms/step
# [[18.999865]]
